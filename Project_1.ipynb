# %%
#Use 
#
#

# %%
import pandas as pd
import numpy as np

# %%
#Read the csv file and assign the name 'MV' to it.
MV=pd.read_csv('Metaverse_tweets.csv')

# %%
#Get rid of hours,minutes,seconds info of column 'user_created' so the column only shows year,month and day(string format).
MV.user_created=MV.user_created.astype(str)
temp=MV['user_created'].tolist()
List=[]
for i in temp:
    i=i[:10]
    List.append(i)
List= pd.DataFrame(List, columns=['user_created'])
MV['user_created']=List['user_created']
MV.head()
# Out:
#       user_name      user_location  \
# 0       Sukatna                NaN
# 1  Onur Rhein 🔺  Wann Deutschland?
# 2        Garcia                NaN
# 3   Aryan Verma        शिमला, भारत
# 4     CryptoSun                 香港
#
#                                     user_description user_created  \
# 0                                                NaN   2021-09-24
# 1  Sular yükseldiğinde balıklar karıncaları yer, ...   2020-03-31
# 2                                                NaN   2021-08-07
# 3                            https://t.co/CwUApCiRJo   2021-07-29
# 4                                           #Bitcoin   2012-04-18
#
#    user_followers user_friends user_favourites user_verified  \
# 0             2.0          116              94         False
# 1           126.0         1401           40101         False
# 2            18.0           85              46         False
# 3             3.0          284             171         False
# ...

# %%
#Change the data type in column 'user_created' to datetime.
MV['user_created'] = pd.to_datetime(MV['user_created'],  errors = 'coerce')
MV.head()
# Out:
#       user_name      user_location  \
# 0       Sukatna                NaN
# 1  Onur Rhein 🔺  Wann Deutschland?
# 2        Garcia                NaN
# 3   Aryan Verma        शिमला, भारत
# 4     CryptoSun                 香港
#
#                                     user_description user_created  \
# 0                                                NaN   2021-09-24
# 1  Sular yükseldiğinde balıklar karıncaları yer, ...   2020-03-31
# 2                                                NaN   2021-08-07
# 3                            https://t.co/CwUApCiRJo   2021-07-29
# 4                                           #Bitcoin   2012-04-18
#
#    user_followers user_friends user_favourites user_verified  \
# 0             2.0          116              94         False
# 1           126.0         1401           40101         False
# 2            18.0           85              46         False
# 3             3.0          284             171         False
# ...

# %%
#Do the same thing for column 'date'.
MV.date=MV.date.astype(str)
temp1=MV['date'].tolist()
List=[]
for i in temp1:
    i=i[:10]
    List.append(i)
List= pd.DataFrame(List, columns=['date'])
MV['date']=List['date']
MV['date'] = pd.to_datetime(MV['date'],  errors = 'coerce')
print(MV.dtypes)
MV.head()
# Out:
# user_name                   object
# user_location               object
# user_description            object
# user_created        datetime64[ns]
# user_followers             float64
# user_friends                object
# user_favourites             object
# user_verified               object
# date                datetime64[ns]
# text                        object
# hashtags                    object
# source                      object
# is_retweet                  object
# dtype: object
#       user_name      user_location  \
# 0       Sukatna                NaN
# 1  Onur Rhein 🔺  Wann Deutschland?
# 2        Garcia                NaN
# 3   Aryan Verma        शिमला, भारत
# 4     CryptoSun                 香港
#
#                                     user_description user_created  \
# 0                                                NaN   2021-09-24
# 1  Sular yükseldiğinde balıklar karıncaları yer, ...   2020-03-31
# 2                                                NaN   2021-08-07
# ...

# %%
#According to the article 'Top 10 Metaverse Stocks in META, the World's First Metaverse ETF' on The Motley Fool-
#a famous private financial and investing advice company, the term 'Metaverse' catapulted into the mainstream in late
#October of 2021 when the social media giant f.m.k.a 'Facebook' announced it was changing its corporate
# Out:
#       user_name      user_location  \
# 0       Sukatna                NaN
# 1  Onur Rhein 🔺  Wann Deutschland?
# 2        Garcia                NaN
# 3   Aryan Verma        शिमला, भारत
# 4     CryptoSun                 香港
#
#                                     user_description user_created  \
# 0                                                NaN   2021-09-24
# 1  Sular yükseldiğinde balıklar karıncaları yer, ...   2020-03-31
# 2                                                NaN   2021-08-07
# 3                            https://t.co/CwUApCiRJo   2021-07-29
# 4                                           #Bitcoin   2012-04-18
#
#    user_followers user_friends user_favourites user_verified       date  \
# 0             2.0          116              94         False 2021-11-15
# 1           126.0         1401           40101         False 2021-11-15
# 2            18.0           85              46         False 2021-11-15
# ...
